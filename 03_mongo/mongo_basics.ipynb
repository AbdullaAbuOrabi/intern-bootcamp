# %%
print("hello")
# Out:
# hello

# %%
list(db.customers.find())
# Out:
# [{'_id': ObjectId('6a1d37379d66856e9430a912'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Dubai',
#   'signup_date': '2025-01-10'},
#  {'_id': ObjectId('6a1d37379d66856e9430a913'),
#   'customer_id': 2,
#   'name': 'Sara Khan',
#   'email': 'sara@example.com',
#   'city': 'Dubai',
#   'signup_date': '2025-02-15'},
#  {'_id': ObjectId('6a1d37379d66856e9430a914'),
#   'customer_id': 3,
#   'name': 'Omar Hassan',
#   'email': 'omar@example.com',
#   'city': 'Sharjah',
#   'signup_date': '2025-03-20'}]

# %% [markdown]
# ## Summary
#
# In this notebook, MongoDB was used to create collections for customers, products, and events.
#
# The notebook demonstrated basic CRUD operations:
#
# | CRUD Operation | MongoDB Method |
# |---|---|
# | Create | insert_one(), insert_many() |
# | Read | find() |
# | Update | update_one() |
# | Delete | delete_one() |
#
# I also practiced filters, projections, and sorting.
#
# MongoDB stores data as flexible documents, while PostgreSQL stores data in structured tables.
#
# PostgreSQL is better when the data has strong relationships and needs strict structure.
#
# MongoDB is better when the data is flexible, nested, or changes often.

# %% [markdown]
# ## MongoDB Query Practice
#
# In this section, I practice MongoDB queries again to make sure I understand how to read, filter, project, and sort documents.

# %%
temporary_customer = {
    "customer_id": 99,
    "name": "Test User",
    "email": "test@example.com",
    "city": "Test City"
}

db.customers.insert_one(temporary_customer)

print("Before delete:")
print(list(db.customers.find({"customer_id": 99})))

db.customers.delete_one({"customer_id": 99})

print("After delete:")
print(list(db.customers.find({"customer_id": 99})))
# Out:
# Before delete:
# [{'_id': ObjectId('6a1d37789d66856e9430a91b'), 'customer_id': 99, 'name': 'Test User', 'email': 'test@example.com', 'city': 'Test City'}]
# After delete:
# []

# %%
list(db.customers.find())
# Out:
# [{'_id': ObjectId('6a1d39dc1de5f57f9e57eaba'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Abu Dhabi',
#   'signup_date': '2025-01-10'},
#  {'_id': ObjectId('6a1d39dc1de5f57f9e57eabb'),
#   'customer_id': 2,
#   'name': 'Sara Khan',
#   'email': 'sara@example.com',
#   'city': 'Dubai',
#   'signup_date': '2025-02-15'},
#  {'_id': ObjectId('6a1d39dc1de5f57f9e57eabc'),
#   'customer_id': 3,
#   'name': 'Omar Hassan',
#   'email': 'omar@example.com',
#   'city': 'Sharjah',
#   'signup_date': '2025-03-20'}]

# %% [markdown]
# ## Delete Document
#
# The `delete_one()` method deletes one document that matches a filter.
#
# This is the Delete part of CRUD.

# %%
list(db.products.find())
# Out:
# [{'_id': ObjectId('6a1d39dc1de5f57f9e57eabd'),
#   'product_id': 1,
#   'product_name': 'Laptop',
#   'category': 'Electronics',
#   'price': 3200},
#  {'_id': ObjectId('6a1d39dc1de5f57f9e57eabe'),
#   'product_id': 2,
#   'product_name': 'Headphones',
#   'category': 'Electronics',
#   'price': 350},
#  {'_id': ObjectId('6a1d39dc1de5f57f9e57eabf'),
#   'product_id': 3,
#   'product_name': 'Office Chair',
#   'category': 'Furniture',
#   'price': 700}]

# %%
db.customers.update_one(
    {"customer_id": 1},
    {"$set": {"city": "Dubai"}}
)

list(db.customers.find({"customer_id": 1}))
# Out:
# [{'_id': ObjectId('6a1d37379d66856e9430a912'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Dubai',
#   'signup_date': '2025-01-10'}]

# %%
list(db.customers.find({"city": "Abu Dhabi"}))
# Out:
# [{'_id': ObjectId('6a1d39dc1de5f57f9e57eaba'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Abu Dhabi',
#   'signup_date': '2025-01-10'}]

# %% [markdown]
# ## Update Document
#
# The `update_one()` method updates one document that matches a filter.
#
# This is the Update part of CRUD.

# %%
list(db.products.find({"category": "Electronics"}))
# Out:
# [{'_id': ObjectId('6a1d39dc1de5f57f9e57eabd'),
#   'product_id': 1,
#   'product_name': 'Laptop',
#   'category': 'Electronics',
#   'price': 3200},
#  {'_id': ObjectId('6a1d39dc1de5f57f9e57eabe'),
#   'product_id': 2,
#   'product_name': 'Headphones',
#   'category': 'Electronics',
#   'price': 350}]

# %%
list(db.events.find({"event_type": "purchase"}))
# Out:
# [{'_id': ObjectId('6a1d37409d66856e9430a91a'),
#   'event_id': 3,
#   'customer_id': 1,
#   'event_type': 'purchase',
#   'product_id': 1,
#   'timestamp': datetime.datetime(2026, 6, 1, 11, 39, 44, 626000)}]

# %%
list(db.customers.find({}, {"_id": 0,"name": 1, "email": 1}))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 list(db.customers.find({}, {"id": 0,"name": 1, "email": 1}))
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1166, in Cursor.__next__(self)
#    1165 def __next__(self) -> _DocumentType:
# -> 1166     return self.next()
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1142, in Cursor.next(self)
#    1140 if self._empty:
#    1141     raise StopIteration
# -> 1142 if len(self._data) or self._refresh():
#    1143     return self._data.popleft()
#    1144 else:
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1090, in Cursor._refresh(self)
#    1068         raise InvalidOperation(
#    1069             "Passing a 'hint' is required when using the min/max query"
#    1070             " option to ensure the query utilizes the correct index"
#    1071         )
#    1072     q = self._query_class(
#    1073         self._query_flags,
#    1074         self._collection.database.name,
#    (...)   1088         self._exhaust,
#    1089     )
# -> 1090     self._send_message(q)
#    1091 elif self._id:  # Get More
#    1092     if self._limit:
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:985, in Cursor._send_message(self, operation)
#     982     raise InvalidOperation("exhaust cursors do not support auto encryption")
#     984 try:
# --> 985     response = client._run_operation(
#     986         operation, self._unpack_response, address=self._address
#     987     )
#     988 except OperationFailure as exc:
#     989     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#     990         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1956, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1946     operation.reset()  # Reset op in case of retry.
#    1947     return server.run_operation(
#    1948         conn,
#    1949         operation,
#    (...)   1953         self,
#    1954     )
# -> 1956 return self._retryable_read(
#    1957     _cmd,
#    1958     operation.read_preference,
#    1959     operation.session,  # type: ignore[arg-type]
#    1960     address=address,
#    1961     retryable=isinstance(operation, _Query),
#    1962     operation=operation.name,
#    1963 )
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2076, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2072 retryable = bool(
#    2073     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2074 )
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_internal(
#    2077         func,
#    2078         s,
#    2079         None,
#    2080         operation,
#    2081         is_read=True,
#    2082         address=address,
#    2083         read_pref=read_pref,
#    2084         retryable=retryable,
#    2085         operation_id=operation_id,
#    2086         is_run_command=is_run_command,
#    2087         is_aggregate_write=is_aggregate_write,
#    2088     )
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2038, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    1995 @_csot.apply
#    1996 def _retry_internal(
#    1997     self,
#    (...)   2008     is_aggregate_write: bool = False,
#    2009 ) -> T:
#    2010     """Internal retryable helper for all client transactions.
#    2011
#    2012     :param func: Callback function we want to retry
#    (...)   2023     :return: Output of the calling func()
#    2024     """
#    2025     return _ClientConnectionRetryable(
#    2026         mongo_client=self,
#    2027         func=func,
#    2028         bulk=bulk,
#    2029         operation=operation,
#    2030         is_read=is_read,
#    2031         session=session,
#    2032         read_pref=read_pref,
#    2033         address=address,
#    2034         retryable=retryable,
#    2035         operation_id=operation_id,
#    2036         is_run_command=is_run_command,
#    2037         is_aggregate_write=is_aggregate_write,
# -> 2038     ).run()
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2811, in _ClientConnectionRetryable.run(self)
#    2809 self._check_last_error(check_csot=True)
#    2810 try:
# -> 2811     res = self._read() if self._is_read else self._write()
#    2812     # Track whether the transaction has completed a command.
#    2813     # If we need to apply backpressure to the first command,
#    2814     # we will need to revert back to starting state.
#    2815     if self._session is not None and self._session.in_transaction:
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:3043, in _ClientConnectionRetryable._read(self)
#    3035 if self._retrying:
#    3036     _debug_log(
#    3037         _COMMAND_LOGGER,
#    3038         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   3041         operationId=self._operation_id,
#    3042     )
# -> 3043 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1940 def _cmd(
#    1941     _session: Optional[ClientSession],
#    1942     server: Server,
#    1943     conn: Connection,
#    1944     read_preference: _ServerMode,
#    1945 ) -> Response:
#    1946     operation.reset()  # Reset op in case of retry.
# -> 1947     return server.run_operation(
#    1948         conn,
#    1949         operation,
#    1950         read_preference,
#    1951         self._event_listeners,
#    1952         unpack_res,
#    1953         self,
#    1954     )
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\helpers.py:53, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      50 from pymongo.synchronous.pool import Connection
#      52 try:
# ---> 53     return func(*args, **kwargs)
#      54 except OperationFailure as exc:
#      55     if no_reauth:
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\synchronous\server.py:227, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     225         first = docs[0]
#     226         operation.client._process_response(first, operation.session)  # type: ignore[misc, arg-type]
# --> 227         _check_command_response(first, conn.max_wire_version, pool_opts=conn.opts)  # type:ignore[has-type]
#     228 except Exception as exc:
#     229     duration = datetime.now() - start
#
# File c:\Users\homam\OneDrive\Desktop\intern-bootcamp\.venv\Lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Cannot do inclusion on field name in exclusion projection, full error: {'ok': 0.0, 'errmsg': 'Cannot do inclusion on field name in exclusion projection', 'code': 31253, 'codeName': 'Location31253'}

# %% [markdown]
# ## Query Events
#
# The events collection stores customer activity.
#
# This query finds only purchase events.

# %%
## Cell 18 — Code


list(db.products.find().sort("price", -1))
# Out:
# [{'_id': ObjectId('6a1d373b9d66856e9430a915'),
#   'product_id': 1,
#   'product_name': 'Laptop',
#   'category': 'Electronics',
#   'price': 3200},
#  {'_id': ObjectId('6a1d373b9d66856e9430a917'),
#   'product_id': 3,
#   'product_name': 'Office Chair',
#   'category': 'Furniture',
#   'price': 700},
#  {'_id': ObjectId('6a1d373b9d66856e9430a916'),
#   'product_id': 2,
#   'product_name': 'Headphones',
#   'category': 'Electronics',
#   'price': 350}]

# %% [markdown]
# ## Sorting
#
# Sorting is used to order the results.
#
# In MongoDB:
#
# - `1` means ascending order
# - `-1` means descending order
#
# The following query sorts products by price from highest to lowest.
#
# SQL equivalent:
#
# ```sql
# SELECT *
# FROM products
# ORDER BY price DESC;

# %%
## Cell 16 — Code


list(db.customers.find({}, {"_id": 0, "name": 1, "email": 1}))
# Out:
# [{'name': 'Ahmed Ali', 'email': 'ahmed@example.com'},
#  {'name': 'Sara Khan', 'email': 'sara@example.com'},
#  {'name': 'Omar Hassan', 'email': 'omar@example.com'}]

# %% [markdown]
# ## Projection
#
# Projection means selecting only specific fields from a document.
#
# In MongoDB projection:
#
# - `1` means show the field
# - `0` means hide the field
#
# The `_id` field is created automatically by MongoDB, so we hide it in this example.
#
# SQL equivalent:
#
# ```sql
# SELECT name, email
# FROM customers;

# %%
## Cell 14 — Code


list(db.customers.find({"city": "Abu Dhabi"}))
# Out:
# [{'_id': ObjectId('6a1d37379d66856e9430a912'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Abu Dhabi',
#   'signup_date': '2025-01-10'}]

# %% [markdown]
# ## Filter Documents
#
# A filter is used to return only documents that match a condition.
#
# The following query finds customers where the city is Abu Dhabi.
#
# SQL equivalent:
#
# ```sql
# SELECT *
# FROM customers
# WHERE city = 'Abu Dhabi';

# %%
list(db.customers.find())
# Out:
# [{'_id': ObjectId('6a1d37379d66856e9430a912'),
#   'customer_id': 1,
#   'name': 'Ahmed Ali',
#   'email': 'ahmed@example.com',
#   'city': 'Abu Dhabi',
#   'signup_date': '2025-01-10'},
#  {'_id': ObjectId('6a1d37379d66856e9430a913'),
#   'customer_id': 2,
#   'name': 'Sara Khan',
#   'email': 'sara@example.com',
#   'city': 'Dubai',
#   'signup_date': '2025-02-15'},
#  {'_id': ObjectId('6a1d37379d66856e9430a914'),
#   'customer_id': 3,
#   'name': 'Omar Hassan',
#   'email': 'omar@example.com',
#   'city': 'Sharjah',
#   'signup_date': '2025-03-20'}]

# %% [markdown]
# ## Read Documents
#
# The `find()` method is used to read documents from a MongoDB collection.
#
# SQL equivalent:
#
# ```sql
# SELECT *
# FROM customers;

# %%
events = [
    {
        "event_id": 1,
        "customer_id": 1,
        "event_type": "view_product",
        "product_id": 1,
        "timestamp": datetime.now()
    },
    {
        "event_id": 2,
        "customer_id": 2,
        "event_type": "add_to_cart",
        "product_id": 2,
        "timestamp": datetime.now()
    },
    {
        "event_id": 3,
        "customer_id": 1,
        "event_type": "purchase",
        "product_id": 1,
        "timestamp": datetime.now()
    }
]

db.events.delete_many({})
db.events.insert_many(events)

print("Events inserted successfully.")
# Out:
# Events inserted successfully.

# %% [markdown]
# ## Insert Event Documents
#
# The events collection stores customer activity.
#
# Examples of events:
#
# - view_product
# - add_to_cart
# - purchase
#
# MongoDB is useful for event data because event data can be flexible and may change over time.

# %%
products = [
    {
        "product_id": 1,
        "product_name": "Laptop",
        "category": "Electronics",
        "price": 3200
    },
    {
        "product_id": 2,
        "product_name": "Headphones",
        "category": "Electronics",
        "price": 350
    },
    {
        "product_id": 3,
        "product_name": "Office Chair",
        "category": "Furniture",
        "price": 700
    }
]

db.products.delete_many({})
db.products.insert_many(products)

print("Products inserted successfully.")
# Out:
# Products inserted successfully.

# %% [markdown]
# ## Insert Product Documents
#
# The products collection stores product documents such as product name, category, and price.

# %%
customers = [
    {
        "customer_id": 1,
        "name": "Ahmed Ali",
        "email": "ahmed@example.com",
        "city": "Abu Dhabi",
        "signup_date": "2025-01-10"
    },
    {
        "customer_id": 2,
        "name": "Sara Khan",
        "email": "sara@example.com",
        "city": "Dubai",
        "signup_date": "2025-02-15"
    },
    {
        "customer_id": 3,
        "name": "Omar Hassan",
        "email": "omar@example.com",
        "city": "Sharjah",
        "signup_date": "2025-03-20"
    }
]

db.customers.delete_many({})
db.customers.insert_many(customers)

print("Customers inserted successfully.")
# Out:
# Customers inserted successfully.

# %% [markdown]
# ## Insert Customer Documents
#
# In MongoDB, collections are created automatically when documents are inserted.
#
# The customers collection stores customer documents.

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client["intern_db"]

print("Connected to MongoDB successfully.")
# Out:
# Connected to MongoDB successfully.

# %%
from datetime import datetime
from pymongo import MongoClient

# %% [markdown]
# # MongoDB Fundamentals
#
# ## Objective
#
# The objective of this notebook is to understand MongoDB basics, create collections, insert documents, and query documents using Python and pymongo.
#
# MongoDB is a NoSQL database that stores data as flexible documents instead of fixed tables.

# %% [markdown]
# ## SQL vs MongoDB Terms
#
# | PostgreSQL / SQL | MongoDB |
# |---|---|
# | Database | Database |
# | Table | Collection |
# | Row | Document |
# | Column | Field |
# | SQL query | MongoDB query |
#
# In PostgreSQL, data is stored in tables with rows and columns.
#
# In MongoDB, data is stored in collections as documents. A document looks similar to a JSON object or Python dictionary.
